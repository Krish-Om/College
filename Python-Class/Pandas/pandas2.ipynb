# %% [markdown]
# # Working with real world datasets

# %%
# %pip install fireducks
# Out:
# Requirement already satisfied: fireducks in /home/krishom/anaconda3/lib/python3.12/site-packages (1.3.2)
# Requirement already satisfied: firefw==1.3.2 in /home/krishom/anaconda3/lib/python3.12/site-packages (from fireducks) (1.3.2)
# Requirement already satisfied: pandas<2.4.0,>=1.5.3 in /home/krishom/anaconda3/lib/python3.12/site-packages (from fireducks) (2.2.2)
# Requirement already satisfied: pyarrow<20.1,>=20.0 in /home/krishom/anaconda3/lib/python3.12/site-packages (from fireducks) (20.0.0)
# Requirement already satisfied: numpy>=1.26.0 in /home/krishom/anaconda3/lib/python3.12/site-packages (from pandas<2.4.0,>=1.5.3->fireducks) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/krishom/anaconda3/lib/python3.12/site-packages (from pandas<2.4.0,>=1.5.3->fireducks) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/krishom/anaconda3/lib/python3.12/site-packages (from pandas<2.4.0,>=1.5.3->fireducks) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/krishom/anaconda3/lib/python3.12/site-packages (from pandas<2.4.0,>=1.5.3->fireducks) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/krishom/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<2.4.0,>=1.5.3->fireducks) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import fireducks.pandas as pd
import matplotlib.pyplot as plt
import os
import warnings
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder,StandardScaler

# %%
df = pd.read_csv("datasets/used_cars.csv")
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>brand</th>
#       <th>model</th>
#       <th>model_year</th>
#       <th>milage</th>
#       <th>fuel_type</th>
#       <th>engine</th>
#       <th>transmission</th>
#       <th>ext_col</th>
#       <th>int_col</th>
#       <th>accident</th>
#       <th>clean_title</th>
#       <th>price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Ford</td>
#       <td>Utility Police Interceptor Base</td>
#       <td>2013</td>
#       <td>51,000 mi.</td>
#       <td>E85 Flex Fuel</td>
#       <td>300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...</td>
#       <td>6-Speed A/T</td>
#       <td>Black</td>
#       <td>Black</td>
#       <td>At least 1 accident or damage reported</td>
#       <td>Yes</td>
#       <td>$10,300</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Hyundai</td>
#       <td>Palisade SEL</td>
#       <td>2021</td>
#       <td>34,742 mi.</td>
#       <td>Gasoline</td>
#       <td>3.8L V6 24V GDI DOHC</td>
#       <td>8-Speed Automatic</td>
#       <td>Moonlight Cloud</td>
#       <td>Gray</td>
#       <td>At least 1 accident or damage reported</td>
#       <td>Yes</td>
#       <td>$38,005</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Lexus</td>
#       <td>RX 350 RX 350</td>
#       <td>2022</td>
#       <td>22,372 mi.</td>
#       <td>Gasoline</td>
#       <td>3.5 Liter DOHC</td>
#       <td>Automatic</td>
#       <td>Blue</td>
#       <td>Black</td>
#       <td>None reported</td>
#       <td>None</td>
#       <td>$54,598</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>INFINITI</td>
#       <td>Q50 Hybrid Sport</td>
#       <td>2015</td>
#       <td>88,900 mi.</td>
#       <td>Hybrid</td>
#       <td>354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...</td>
#       <td>7-Speed A/T</td>
#       <td>Black</td>
#       <td>Black</td>
#       <td>None reported</td>
#       <td>Yes</td>
#       <td>$15,500</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Audi</td>
#       <td>Q3 45 S line Premium Plus</td>
#       <td>2021</td>
#       <td>9,835 mi.</td>
#       <td>Gasoline</td>
#       <td>2.0L I4 16V GDI DOHC Turbo</td>
#       <td>8-Speed Automatic</td>
#       <td>Glacier White Metallic</td>
#       <td>Black</td>
#       <td>None reported</td>
#       <td>None</td>
#       <td>$34,999</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>brand</th>
#       <th>model</th>
#       <th>model_year</th>
#       <th>milage</th>
#       <th>fuel_type</th>
#       <th>engine</th>
#       <th>transmission</th>
#       <th>ext_col</th>
#       <th>int_col</th>
#       <th>accident</th>
#       <th>clean_title</th>
#       <th>price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Ford</td>
#       <td>Utility Police Interceptor Base</td>
#       <td>2013</td>
#       <td>51,000 mi.</td>
#       <td>E85 Flex Fuel</td>
#       <td>300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...</td>
#       <td>6-Speed A/T</td>
#       <td>Black</td>
#       <td>Black</td>
#       <td>At least 1 accident or damage reported</td>
#       <td>Yes</td>
#       <td>$10,300</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Hyundai</td>
#       <td>Palisade SEL</td>
#       <td>2021</td>
#       <td>34,742 mi.</td>
#       <td>Gasoline</td>
#       <td>3.8L V6 24V GDI DOHC</td>
#       <td>8-Speed Automatic</td>
#       <td>Moonlight Cloud</td>
#       <td>Gray</td>
#       <td>At least 1 accident or damage reported</td>
#       <td>Yes</td>
#       <td>$38,005</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Lexus</td>
#       <td>RX 350 RX 350</td>
#       <td>2022</td>
#       <td>22,372 mi.</td>
#       <td>Gasoline</td>
#       <td>3.5 Liter DOHC</td>
#       <td>Automatic</td>
#       <td>Blue</td>
#       <td>Black</td>
#       <td>None reported</td>
#       <td>None</td>
#       <td>$54,598</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>INFINITI</td>
#       <td>Q50 Hybrid Sport</td>
#       <td>2015</td>
#       <td>88,900 mi.</td>
#       <td>Hybrid</td>
#       <td>354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...</td>
#       <td>7-Speed A/T</td>
#       <td>Black</td>
#       <td>Black</td>
#       <td>None reported</td>
#       <td>Yes</td>
#       <td>$15,500</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Audi</td>
#       <td>Q3 45 S line Premium Plus</td>
#       <td>2021</td>
#       <td>9,835 mi.</td>
#       <td>Gasoline</td>
#       <td>2.0L I4 16V GDI DOHC Turbo</td>
#       <td>8-Speed Automatic</td>
#       <td>Glacier White Metallic</td>
#       <td>Black</td>
#       <td>None reported</td>
#       <td>None</td>
#       <td>$34,999</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.shape
# Out:
# (4009, 12)

# %%
# pd.set_option("display.max_rows",None)
# pd.set_option("display.max_columns",None)
# pd.set_option("display.max_colwidth",None)

# %%
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>brand</th>
#       <th>model</th>
#       <th>model_year</th>
#       <th>milage</th>
#       <th>fuel_type</th>
#       <th>engine</th>
#       <th>transmission</th>
#       <th>ext_col</th>
#       <th>int_col</th>
#       <th>accident</th>
#       <th>clean_title</th>
#       <th>price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Ford</td>
#       <td>Utility Police Interceptor Base</td>
#       <td>2013</td>
#       <td>51,000 mi.</td>
#       <td>E85 Flex Fuel</td>
#       <td>300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...</td>
#       <td>6-Speed A/T</td>
#       <td>Black</td>
#       <td>Black</td>
#       <td>At least 1 accident or damage reported</td>
#       <td>Yes</td>
#       <td>$10,300</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Hyundai</td>
#       <td>Palisade SEL</td>
#       <td>2021</td>
#       <td>34,742 mi.</td>
#       <td>Gasoline</td>
#       <td>3.8L V6 24V GDI DOHC</td>
#       <td>8-Speed Automatic</td>
#       <td>Moonlight Cloud</td>
#       <td>Gray</td>
#       <td>At least 1 accident or damage reported</td>
#       <td>Yes</td>
#       <td>$38,005</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Lexus</td>
#       <td>RX 350 RX 350</td>
#       <td>2022</td>
#       <td>22,372 mi.</td>
#       <td>Gasoline</td>
#       <td>3.5 Liter DOHC</td>
#       <td>Automatic</td>
#       <td>Blue</td>
#       <td>Black</td>
#       <td>None reported</td>
#       <td>None</td>
#       <td>$54,598</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>INFINITI</td>
#       <td>Q50 Hybrid Sport</td>
#       <td>2015</td>
#       <td>88,900 mi.</td>
#       <td>Hybrid</td>
#       <td>354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...</td>
#       <td>7-Speed A/T</td>
#       <td>Black</td>
#       <td>Black</td>
#       <td>None reported</td>
#       <td>Yes</td>
#       <td>$15,500</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Audi</td>
#       <td>Q3 45 S line Premium Plus</td>
#       <td>2021</td>
#       <td>9,835 mi.</td>
#       <td>Gasoline</td>
#       <td>2.0L I4 16V GDI DOHC Turbo</td>
#       <td>8-Speed Automatic</td>
#       <td>Glacier White Metallic</td>
#       <td>Black</td>
#       <td>None reported</td>
#       <td>None</td>
#       <td>$34,999</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>4004</th>
#       <td>Bentley</td>
#       <td>Continental GT Speed</td>
#       <td>2023</td>
#       <td>714 mi.</td>
#       <td>Gasoline</td>
#       <td>6.0L W12 48V PDI DOHC Twin Turbo</td>
#       <td>8-Speed Automatic with Auto-Shift</td>
#       <td>C / C</td>
#       <td>Hotspur</td>
#       <td>None reported</td>
#       <td>Yes</td>
#       <td>$349,950</td>
#     </tr>
#     <tr>
#       <th>4005</th>
#       <td>Audi</td>
#       <td>S4 3.0T Premium Plus</td>
#       <td>2022</td>
#       <td>10,900 mi.</td>
#       <td>Gasoline</td>
#       <td>349.0HP 3.0L V6 Cylinder Engine Gasoline Fuel</td>
#       <td>Transmission w/Dual Shift Mode</td>
#       <td>Black</td>
#       <td>Black</td>
#       <td>None reported</td>
#       <td>Yes</td>
#       <td>$53,900</td>
#     </tr>
#     <tr>
#       <th>4006</th>
#       <td>Porsche</td>
#       <td>Taycan</td>
#       <td>2022</td>
#       <td>2,116 mi.</td>
#       <td>None</td>
#       <td>Electric</td>
#       <td>Automatic</td>
#       <td>Black</td>
#       <td>Black</td>
#       <td>None reported</td>
#       <td>None</td>
#       <td>$90,998</td>
#     </tr>
#     <tr>
#       <th>4007</th>
#       <td>Ford</td>
#       <td>F-150 Raptor</td>
#       <td>2020</td>
#       <td>33,000 mi.</td>
#       <td>Gasoline</td>
#       <td>450.0HP 3.5L V6 Cylinder Engine Gasoline Fuel</td>
#       <td>A/T</td>
#       <td>Blue</td>
#       <td>Black</td>
#       <td>None reported</td>
#       <td>Yes</td>
#       <td>$62,999</td>
#     </tr>
#     <tr>
#       <th>4008</th>
#       <td>BMW</td>
#       <td>X3 xDrive30i</td>
#       <td>2020</td>
#       <td>43,000 mi.</td>
#       <td>Gasoline</td>
#       <td>248.0HP 2.0L 4 Cylinder Engine Gasoline Fuel</td>
#       <td>A/T</td>
#       <td>Gray</td>
#       <td>Brown</td>
#       <td>At least 1 accident or damage reported</td>
#       <td>Yes</td>
#       <td>$40,000</td>
#     </tr>
#   </tbody>
# </table>
# <p>4009 rows x 12 columns</p>
# </div>

# %%
df.info()
# Out:
# <class 'fireducks.pandas.frame.DataFrame'>
# RangeIndex: 4009 entries, 0 to 4008
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         4009 non-null   object
#  1   model         4009 non-null   object
#  2   model_year    4009 non-null   int64
#  3   milage        4009 non-null   object
#  4   fuel_type     3839 non-null   object
#  5   engine        4009 non-null   object
#  6   transmission  4009 non-null   object
#  7   ext_col       4009 non-null   object
#  8   int_col       4009 non-null   object
#  9   accident      3896 non-null   object
#  10  clean_title   3413 non-null   object
#  11  price         4009 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 375.9+ KB

# %%
df['milage']=df['milage'].str.replace("mi.","").str.replace(",","")

# %%
df['milage']= df['milage'].astype(int)

# %%
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/lib/python3.12/site-packages/IPython/core/formatters.py:925, in IPythonDisplayFormatter.__call__(self, obj)
#     923 method = get_real_method(obj, self.print_method)
#     924 if method is not None:
# --> 925     method()
#     926     return True
#
# File ~/anaconda3/lib/python3.12/site-packages/fireducks/pandas/frame.py:354, in DataFrame._ipython_display_(self)
#     348 from IPython.display import display
#     350 if is_notebook_like():
#     351     # notebook by-default prints in html-format
#     352     # hence, to avoid calling all available formatters and select
#     353     # the suitable one based on UI, limiting the format to html only
# --> 354     data = {"text/html": self._repr_html_()}
#     355 elif is_interactive_terminal():
#     356     # terminal by-default prints in text-format
#     357     data = {"text/plain": "\n" + repr(self)}
#
# File ~/anaconda3/lib/python3.12/site-packages/fireducks/pandas/frame.py:383, in DataFrame._repr_html_(self)
#     382 def _repr_html_(self):
# --> 383     ret, is_trunc = self.__get_trunc_repr_method_result__(
#     384         method="_repr_html_"
#     385     )
#     386     if is_trunc:
#     387         truncated_shape_info = "\n".join(ret.rsplit("\n", 2)[1:])
#
# File ~/anaconda3/lib/python3.12/site-packages/fireducks/pandas/generic.py:781, in FireDucksPandasCompat.__get_trunc_repr_method_result__(self, method)
#     771 if self._fireducks_meta.is_cached("pandas_object"):
#     772     return (
#     773         utils._wrap(
#     774             getattr(
#    (...)
#     778         False,
#     779     )
# --> 781 n = len(self)
#     782 minr, maxr = (
#     783     pandas.get_option("display.min_rows"),
#     784     pandas.get_option("display.max_rows"),
#     785 )
#     786 need_truncation = maxr is not None and n > maxr
#
# File ~/anaconda3/lib/python3.12/site-packages/fireducks/pandas/frame.py:318, in DataFrame.__len__(self)
#     317 def __len__(self):
# --> 318     return self.shape[0]
#
# File ~/anaconda3/lib/python3.12/site-packages/fireducks/pandas/frame.py:1584, in DataFrame.shape(self)
#    1582 @property
#    1583 def shape(self) -> tuple[int, int]:
# -> 1584     return self._get_shape()
#
# File ~/anaconda3/lib/python3.12/site-packages/fireducks/pandas/generic.py:1336, in FireDucksPandasCompat._get_shape(self)
#    1334 if not self._fireducks_meta.is_cached("shape"):
#    1335     value = ir.get_shape(self._value)
# -> 1336     shape = fireducks.core.evaluate([value])[0]
#    1337     self._fireducks_meta.set_cache("shape", (shape.y, shape.x))
#    1338 return self._fireducks_meta.get_cache("shape")
#
# File ~/anaconda3/lib/python3.12/site-packages/fireducks/core.py:403, in evaluate(values, options, evalLogger)
#     397 def evaluate(
#     398     values: List[fire.Value],
#     399     options: EvalOptions = None,
#     400     evalLogger: EvalLogger = None,
#     401 ):
#     402     with tracing.scope(tracing.Level.DEFAULT, "fireducks.core.evaluate"):
# --> 403         ret = _evaluate(values, options, evalLogger)
#     404     return ret
#
# File ~/anaconda3/lib/python3.12/site-packages/fireducks/core.py:382, in _evaluate(values, options, evalLogger)
#     374     return fireducks_ext.execute(
#     375         context().ext_context,
#     376         options._compile_options,
#     377         fi,
#     378         evalLogger._extLogger if evalLogger is not None else None,
#     379     )
#     381 try:
# --> 382     return fire.evaluate(values, wrapper, package="fireducks")
#     383 except fireducks_ext.IndexingError as e:
#     384     raise pandas.errors.IndexingError(e)
#
# File ~/anaconda3/lib/python3.12/site-packages/firefw/runtime.py:31, in prohibit_reentrant.<locals>.wrapper(*args, **kwargs)
#      29 lock = True
#      30 try:
# ---> 31     ret = func(*args, **kwargs)
#      32 finally:
#      33     lock = False
#
# File ~/anaconda3/lib/python3.12/site-packages/firefw/runtime.py:72, in evaluate(values, executor, package)
#      67 with tracing.scope(tracing.Level.VERBOSE, "create_mlir_func"):
#      68     source, input_values, output_values = create_mlir_func(
#      69         values, package=package
#      70     )
# ---> 72 ret = executor(source, input_values, output_values)
#      74 if len(output_values) != len(ret):
#      75     raise RuntimeError("Executor did not return enough number of returns")
#
# File ~/anaconda3/lib/python3.12/site-packages/fireducks/core.py:374, in _evaluate.<locals>.wrapper(ir, input_values, output_values)
#     371 fi.input_values = [v.get_result() for v in input_values]
#     372 fi.output_types = [v.mlir_type for v in output_values]
# --> 374 return fireducks_ext.execute(
#     375     context().ext_context,
#     376     options._compile_options,
#     377     fi,
#     378     evalLogger._extLogger if evalLogger is not None else None,
#     379 )
#
# ValueError: Failed to parse string: '195 ' as a scalar of type int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/lib/python3.12/site-packages/IPython/core/formatters.py:711, in PlainTextFormatter.__call__(self, obj)
#     704 stream = StringIO()
#     705 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     706     self.max_width, self.newline,
#     707     max_seq_length=self.max_seq_length,
#     708     singleton_pprinters=self.singleton_printers,
#     709     type_pprinters=self.type_printers,
#     710     deferred_pprinters=self.deferred_printers)
# --> 711 printer.pretty(obj)
#     712 printer.flush()
#     713 return stream.getvalue()
#
# File ~/anaconda3/lib/python3.12/site-packages/IPython/lib/pretty.py:419, in RepresentationPrinter.pretty(self, obj)
#     408                         return meth(obj, self, cycle)
#     409                 if (
#     410                     cls is not object
#     411                     # check if cls defines __repr__
#    (...)
#     417                     and callable(_safe_getattr(cls, "__repr__", None))
#     418                 ):
# --> 419                     return _repr_pprint(obj, self, cycle)
#     421     return _default_pprint(obj, self, cycle)
#     422 finally:
#
# File ~/anaconda3/lib/python3.12/site-packages/IPython/lib/pretty.py:787, in _repr_pprint(obj, p, cycle)
#     785 """A pprint that just redirects to the normal repr function."""
#     786 # Find newlines and replace them with p.break_()
# --> 787 output = repr(obj)
#     788 lines = output.splitlines()
#     789 with p.group():
#
# File ~/anaconda3/lib/python3.12/site-packages/fireducks/pandas/frame.py:367, in DataFrame.__repr__(self)
#     366 def __repr__(self):
# --> 367     ret, is_trunc = self.__get_trunc_repr_method_result__(
#     368         method="__repr__"
#     369     )
#     370     if is_trunc:
#     371         truncated_shape_info = ret.rsplit("\n", 1)[1]
#
# File ~/anaconda3/lib/python3.12/site-packages/fireducks/pandas/generic.py:781, in FireDucksPandasCompat.__get_trunc_repr_method_result__(self, method)
#     771 if self._fireducks_meta.is_cached("pandas_object"):
#     772     return (
#     773         utils._wrap(
#     774             getattr(
#    (...)
#     778         False,
#     779     )
# --> 781 n = len(self)
#     782 minr, maxr = (
#     783     pandas.get_option("display.min_rows"),
#     784     pandas.get_option("display.max_rows"),
#     785 )
#     786 need_truncation = maxr is not None and n > maxr
#
# File ~/anaconda3/lib/python3.12/site-packages/fireducks/pandas/frame.py:318, in DataFrame.__len__(self)
#     317 def __len__(self):
# --> 318     return self.shape[0]
#
# File ~/anaconda3/lib/python3.12/site-packages/fireducks/pandas/frame.py:1584, in DataFrame.shape(self)
#    1582 @property
#    1583 def shape(self) -> tuple[int, int]:
# -> 1584     return self._get_shape()
#
# File ~/anaconda3/lib/python3.12/site-packages/fireducks/pandas/generic.py:1336, in FireDucksPandasCompat._get_shape(self)
#    1334 if not self._fireducks_meta.is_cached("shape"):
#    1335     value = ir.get_shape(self._value)
# -> 1336     shape = fireducks.core.evaluate([value])[0]
#    1337     self._fireducks_meta.set_cache("shape", (shape.y, shape.x))
#    1338 return self._fireducks_meta.get_cache("shape")
#
# File ~/anaconda3/lib/python3.12/site-packages/fireducks/core.py:403, in evaluate(values, options, evalLogger)
#     397 def evaluate(
#     398     values: List[fire.Value],
#     399     options: EvalOptions = None,
#     400     evalLogger: EvalLogger = None,
#     401 ):
#     402     with tracing.scope(tracing.Level.DEFAULT, "fireducks.core.evaluate"):
# --> 403         ret = _evaluate(values, options, evalLogger)
#     404     return ret
#
# File ~/anaconda3/lib/python3.12/site-packages/fireducks/core.py:382, in _evaluate(values, options, evalLogger)
#     374     return fireducks_ext.execute(
#     375         context().ext_context,
#     376         options._compile_options,
#     377         fi,
#     378         evalLogger._extLogger if evalLogger is not None else None,
#     379     )
#     381 try:
# --> 382     return fire.evaluate(values, wrapper, package="fireducks")
#     383 except fireducks_ext.IndexingError as e:
#     384     raise pandas.errors.IndexingError(e)
#
# File ~/anaconda3/lib/python3.12/site-packages/firefw/runtime.py:31, in prohibit_reentrant.<locals>.wrapper(*args, **kwargs)
#      29 lock = True
#      30 try:
# ---> 31     ret = func(*args, **kwargs)
#      32 finally:
#      33     lock = False
#
# File ~/anaconda3/lib/python3.12/site-packages/firefw/runtime.py:72, in evaluate(values, executor, package)
#      67 with tracing.scope(tracing.Level.VERBOSE, "create_mlir_func"):
#      68     source, input_values, output_values = create_mlir_func(
#      69         values, package=package
#      70     )
# ---> 72 ret = executor(source, input_values, output_values)
#      74 if len(output_values) != len(ret):
#      75     raise RuntimeError("Executor did not return enough number of returns")
#
# File ~/anaconda3/lib/python3.12/site-packages/fireducks/core.py:374, in _evaluate.<locals>.wrapper(ir, input_values, output_values)
#     371 fi.input_values = [v.get_result() for v in input_values]
#     372 fi.output_types = [v.mlir_type for v in output_values]
# --> 374 return fireducks_ext.execute(
#     375     context().ext_context,
#     376     options._compile_options,
#     377     fi,
#     378     evalLogger._extLogger if evalLogger is not None else None,
#     379 )
#
# ValueError: Failed to parse string: '195 ' as a scalar of type int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/lib/python3.12/site-packages/IPython/core/formatters.py:347, in BaseFormatter.__call__(self, obj)
#     345     method = get_real_method(obj, self.print_method)
#     346     if method is not None:
# --> 347         return method()
#     348     return None
#     349 else:
#
# File ~/anaconda3/lib/python3.12/site-packages/fireducks/pandas/frame.py:383, in DataFrame._repr_html_(self)
#     382 def _repr_html_(self):
# --> 383     ret, is_trunc = self.__get_trunc_repr_method_result__(
#     384         method="_repr_html_"
#     385     )
#     386     if is_trunc:
#     387         truncated_shape_info = "\n".join(ret.rsplit("\n", 2)[1:])
#
# File ~/anaconda3/lib/python3.12/site-packages/fireducks/pandas/generic.py:781, in FireDucksPandasCompat.__get_trunc_repr_method_result__(self, method)
#     771 if self._fireducks_meta.is_cached("pandas_object"):
#     772     return (
#     773         utils._wrap(
#     774             getattr(
#    (...)
#     778         False,
#     779     )
# --> 781 n = len(self)
#     782 minr, maxr = (
#     783     pandas.get_option("display.min_rows"),
#     784     pandas.get_option("display.max_rows"),
#     785 )
#     786 need_truncation = maxr is not None and n > maxr
#
# File ~/anaconda3/lib/python3.12/site-packages/fireducks/pandas/frame.py:318, in DataFrame.__len__(self)
#     317 def __len__(self):
# --> 318     return self.shape[0]
#
# File ~/anaconda3/lib/python3.12/site-packages/fireducks/pandas/frame.py:1584, in DataFrame.shape(self)
#    1582 @property
#    1583 def shape(self) -> tuple[int, int]:
# -> 1584     return self._get_shape()
#
# File ~/anaconda3/lib/python3.12/site-packages/fireducks/pandas/generic.py:1336, in FireDucksPandasCompat._get_shape(self)
#    1334 if not self._fireducks_meta.is_cached("shape"):
#    1335     value = ir.get_shape(self._value)
# -> 1336     shape = fireducks.core.evaluate([value])[0]
#    1337     self._fireducks_meta.set_cache("shape", (shape.y, shape.x))
#    1338 return self._fireducks_meta.get_cache("shape")
#
# File ~/anaconda3/lib/python3.12/site-packages/fireducks/core.py:403, in evaluate(values, options, evalLogger)
#     397 def evaluate(
#     398     values: List[fire.Value],
#     399     options: EvalOptions = None,
#     400     evalLogger: EvalLogger = None,
#     401 ):
#     402     with tracing.scope(tracing.Level.DEFAULT, "fireducks.core.evaluate"):
# --> 403         ret = _evaluate(values, options, evalLogger)
#     404     return ret
#
# File ~/anaconda3/lib/python3.12/site-packages/fireducks/core.py:382, in _evaluate(values, options, evalLogger)
#     374     return fireducks_ext.execute(
#     375         context().ext_context,
#     376         options._compile_options,
#     377         fi,
#     378         evalLogger._extLogger if evalLogger is not None else None,
#     379     )
#     381 try:
# --> 382     return fire.evaluate(values, wrapper, package="fireducks")
#     383 except fireducks_ext.IndexingError as e:
#     384     raise pandas.errors.IndexingError(e)
#
# File ~/anaconda3/lib/python3.12/site-packages/firefw/runtime.py:31, in prohibit_reentrant.<locals>.wrapper(*args, **kwargs)
#      29 lock = True
#      30 try:
# ---> 31     ret = func(*args, **kwargs)
#      32 finally:
#      33     lock = False
#
# File ~/anaconda3/lib/python3.12/site-packages/firefw/runtime.py:72, in evaluate(values, executor, package)
#      67 with tracing.scope(tracing.Level.VERBOSE, "create_mlir_func"):
#      68     source, input_values, output_values = create_mlir_func(
#      69         values, package=package
#      70     )
# ---> 72 ret = executor(source, input_values, output_values)
#      74 if len(output_values) != len(ret):
#      75     raise RuntimeError("Executor did not return enough number of returns")
#
# File ~/anaconda3/lib/python3.12/site-packages/fireducks/core.py:374, in _evaluate.<locals>.wrapper(ir, input_values, output_values)
#     371 fi.input_values = [v.get_result() for v in input_values]
#     372 fi.output_types = [v.mlir_type for v in output_values]
# --> 374 return fireducks_ext.execute(
#     375     context().ext_context,
#     376     options._compile_options,
#     377     fi,
#     378     evalLogger._extLogger if evalLogger is not None else None,
#     379 )
#
# ValueError: Failed to parse string: '195 ' as a scalar of type int64
