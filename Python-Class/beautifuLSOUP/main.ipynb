# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

from bs4 import BeautifulSoup

soup = BeautifulSoup(html_doc)

# %%
# soup.abish.string
# Out:
# "The Dormouse's story"

# %%
# !uv pip install requests
# Out:
# Using Python 3.13.5 environment at: /home/krishom/College/Python-Class/.venv
# Resolved 5 packages in 656ms
# ⠙ Preparing packages... (0/5)
# ⠙ Preparing packages... (0/5)--------------     0 B/144.77 KiB
# ⠙ Preparing packages... (0/5)--------------     0 B/144.77 KiB
# charset-normalizer   ------------------------------     0 B/144.77 KiB
# ⠙ Preparing packages... (0/5)--------------     0 B/158.91 KiB
# charset-normalizer   ------------------------------     0 B/144.77 KiB
# ⠙ Preparing packages... (0/5)--------------     0 B/158.91 KiB
# charset-normalizer   ------------------------------     0 B/144.77 KiB
# ⠙ Preparing packages... (0/5)--------------     0 B/158.91 KiB
# idna                 ------------------------------     0 B/68.79 KiB
# charset-normalizer   ------------------------------     0 B/144.77 KiB
# ⠙ Preparing packages... (0/5)--------------     0 B/158.91 KiB
# idna                 ------------------------------     0 B/68.79 KiB
# charset-normalizer   ------------------------------     0 B/144.77 KiB
# ⠙ Preparing packages... (0/5)--------------     0 B/158.91 KiB
# idna                 ------------------------------     0 B/68.79 KiB
# charset-normalizer   ------------------------------     0 B/144.77 KiB
# ⠙ Preparing packages... (0/5)--------------     0 B/158.91 KiB
# idna                 ------------------------------     0 B/68.79 KiB
# charset-normalizer   ------------------------------     0 B/144.77 KiB
# ⠙ Preparing packages... (0/5)--------------     0 B/158.91 KiB
# idna                 ------------------------------     0 B/68.79 KiB
# urllib3              ------------------------------     0 B/126.75 KiB
# charset-normalizer   ------------------------------     0 B/144.77 KiB
# ⠙ Preparing packages... (0/5)--------------     0 B/158.91 KiB
# idna                 ------------------------------     0 B/68.79 KiB
# urllib3              ------------------------------     0 B/126.75 KiB
# charset-normalizer   ------------------------------     0 B/144.77 KiB
# ⠙ Preparing packages... (0/5)--------------     0 B/158.91 KiB
# idna                 ------------------------------     0 B/68.79 KiB
# urllib3              ------------------------------     0 B/126.75 KiB
# charset-normalizer   ------------------------------     0 B/144.77 KiB
# ⠙ Preparing packages... (0/5)--------------     0 B/158.91 KiB
# idna                 ------------------------------     0 B/68.79 KiB
# urllib3              ------------------------------     0 B/126.75 KiB
# charset-normalizer   ------------------------------     0 B/144.77 KiB
# ⠙ Preparing packages... (0/5)--------------     0 B/158.91 KiB
# idna                 ------------------------------     0 B/68.79 KiB
# urllib3              ------------------------------     0 B/126.75 KiB
# charset-normalizer   ------------------------------     0 B/144.77 KiB
# ⠙ Preparing packages... (0/5)--------------     0 B/158.91 KiB
# requests             ------------------------------     0 B/63.33 KiB
# idna                 ------------------------------     0 B/68.79 KiB
# urllib3              ------------------------------     0 B/126.75 KiB
# charset-normalizer   ------------------------------     0 B/144.77 KiB
# ⠙ Preparing packages... (0/5)--------------     0 B/158.91 KiB
# requests             ------------------------------     0 B/63.33 KiB
# idna                 ------------------------------     0 B/68.79 KiB
# urllib3              ------------------------------     0 B/126.75 KiB
# charset-normalizer   ------------------------------ 16.00 KiB/144.77 KiB
# ⠙ Preparing packages... (0/5)--------------     0 B/158.91 KiB
# requests             ------------------------------     0 B/63.33 KiB
# idna                 ------------------------------     0 B/68.79 KiB
# urllib3              ------------------------------     0 B/126.75 KiB
# charset-normalizer   ------------------------------ 16.00 KiB/144.77 KiB
# ⠙ Preparing packages... (0/5)-------------- 14.88 KiB/158.91 KiB
# requests             ------------------------------     0 B/63.33 KiB
# idna                 ------------------------------ 14.89 KiB/68.79 KiB
# urllib3              ------------------------------     0 B/126.75 KiB
# charset-normalizer   ------------------------------ 16.00 KiB/144.77 KiB
# ⠹ Preparing packages... (0/5)-------------- 14.88 KiB/158.91 KiB
# requests             ------------------------------     0 B/63.33 KiB
# idna                 ------------------------------ 14.89 KiB/68.79 KiB
# urllib3              ------------------------------     0 B/126.75 KiB
# charset-normalizer   ------------------------------ 16.00 KiB/144.77 KiB
# ⠹ Preparing packages... (0/5)-------------- 14.88 KiB/158.91 KiB
# requests             ------------------------------     0 B/63.33 KiB
# idna                 ------------------------------ 14.89 KiB/68.79 KiB
# urllib3              ------------------------------ 7.67 KiB/126.75 KiB
# charset-normalizer   ------------------------------ 16.00 KiB/144.77 KiB
# ⠹ Preparing packages... (0/5)-------------- 14.88 KiB/158.91 KiB
# requests             ------------------------------ 2.69 KiB/63.33 KiB
# idna                 ------------------------------ 14.89 KiB/68.79 KiB
# urllib3              ------------------------------ 7.67 KiB/126.75 KiB
# charset-normalizer   ------------------------------ 16.00 KiB/144.77 KiB
# ⠹ Preparing packages... (0/5)-------------- 14.88 KiB/158.91 KiB
# requests             ------------------------------ 10.77 KiB/63.33 KiB
# idna                 ------------------------------ 22.97 KiB/68.79 KiB
# urllib3              ------------------------------ 14.88 KiB/126.75 KiB
# charset-normalizer   ------------------------------ 26.77 KiB/144.77 KiB
# ⠹ Preparing packages... (0/5)-------------- 20.26 KiB/158.91 KiB
# requests             ------------------------------ 10.77 KiB/63.33 KiB
# idna                 ------------------------------ 38.97 KiB/68.79 KiB
# urllib3              ------------------------------ 14.88 KiB/126.75 KiB
# charset-normalizer   ------------------------------ 26.77 KiB/144.77 KiB
# ⠹ Preparing packages... (0/5)-------------- 36.26 KiB/158.91 KiB
# requests             ------------------------------ 14.88 KiB/63.33 KiB
# idna                 ------------------------------ 38.97 KiB/68.79 KiB
# urllib3              ------------------------------ 14.88 KiB/126.75 KiB
# charset-normalizer   ------------------------------ 42.77 KiB/144.77 KiB
# ⠸ Preparing packages... (0/5)-------------- 52.26 KiB/158.91 KiB
# requests             ------------------------------ 14.88 KiB/63.33 KiB
# idna                 ------------------------------ 64.89 KiB/68.79 KiB
# urllib3              ------------------------------ 14.88 KiB/126.75 KiB
# charset-normalizer   ------------------------------ 61.23 KiB/144.77 KiB
# ⠸ Preparing packages... (0/5)-------------- 78.88 KiB/158.91 KiB
# requests             ------------------------------ 14.88 KiB/63.33 KiB
# urllib3              ------------------------------ 14.88 KiB/126.75 KiB
# charset-normalizer   ------------------------------ 61.23 KiB/144.77 KiB
# ⠸ Preparing packages... (0/5)-------------- 78.88 KiB/158.91 KiB
# requests             ------------------------------ 30.88 KiB/63.33 KiB
# urllib3              ------------------------------ 30.88 KiB/126.75 KiB
# charset-normalizer   ------------------------------ 61.23 KiB/144.77 KiB
# ⠸ Preparing packages... (0/5)-------------- 78.88 KiB/158.91 KiB
# urllib3              ------------------------------ 75.99 KiB/126.75 KiB
# charset-normalizer   ------------------------------ 61.23 KiB/144.77 KiB
# ⠸ Preparing packages... (0/5)-------------- 78.88 KiB/158.91 KiB
# urllib3              ------------------------------ 75.99 KiB/126.75 KiB
# charset-normalizer   ------------------------------ 77.23 KiB/144.77 KiB
# ⠸ Preparing packages... (0/5)2m------------ 94.88 KiB/158.91 KiB
# urllib3              ------------------------------ 123.99 KiB/126.75 KiB
# charset-normalizer   ------------------------------ 109.23 KiB/144.77 KiB
# ⠸ Preparing packages... (0/5)---------- 126.78 KiB/158.91 KiB
# charset-normalizer   ------------------------------ 125.23 KiB/144.77 KiB
# ⠸ Preparing packages... (0/5)---------- 142.88 KiB/158.91 KiB
# charset-normalizer   ------------------------------ 141.23 KiB/144.77 KiB
# ⠼ Preparing packages... (3/5)---------- 158.88 KiB/158.91 KiB
# Prepared 5 packages in 604ms
# Installed 5 packages in 26ms.4.2
#  + certifi==2025.7.14
#  + charset-normalizer==3.4.2
#  + idna==3.10
#  + requests==2.32.4
#  + urllib3==2.5.0

# %%
import requests
r = requests.get("https://parallelum.com.br/fipe/api/v1/carros/marcas")
data = r.json()

import pandas as pd
real = pd.read_csv
data = pd.DataFrame(data)
# Out:
#     codigo             nome
# 0        1            Acura
# 1        2           Agrale
# 2        3       Alfa Romeo
# 3        4           AM Gen
# 4        5      Asia Motors
# ..     ...              ...
# 98      58            Volvo
# 99      59  VW - VolksWagen
# 100    163             Wake
# 101    120             Walk
# 102    253            ZEEKR
#
# [103 rows x 2 columns]
